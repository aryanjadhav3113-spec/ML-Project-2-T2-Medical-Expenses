# %%
import numpy as np
import pandas  as pd

# %%
data = pd.read_csv(r'C:\Users\Aryan\OneDrive\Desktop\Copy of med-insurance.xlsx')
data.shape
# Out:
#   Cell In[5], line 1
#     data = pd.read_csv(r,'C:\Users\Aryan\OneDrive\Desktop\Copy of med-insurance.xlsx')
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

data = pd.read_excel(r'C:\Users\Aryan\OneDrive\Desktop\Copy of med-insurance.xlsx')

print(data.shape)
# Out:
# (1338, 7)

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# #  Use Label Encoder to encode Categorical Columns

# %% [markdown]
# # Check the Distribution of Expenses column

# %%
Apply log Transformation intothe Expenses column

# %%
Apply Splitting

# %%
Apply Standard Scaling

# %%
Apply Linear Regrssion Model

# %%
Evaluate the Model Performance
